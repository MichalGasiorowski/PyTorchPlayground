# %%
from os.path import join
from google.colab import drive

ROOT = "/content/drive"
drive.mount(ROOT)

PROJ = "My Drive/Colab Notebooks/Workspace/PyTorchPlayground" # This is a custom path.
PROJECT_PATH = join(ROOT, PROJ)

#from google.colab import drive
#pdrive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os

os.listdir(PROJECT_PATH)
# Out:
# ['RunBuilder.py',
#  '__pycache__',
#  'plotcm.py',
#  'Network.py',
#  'runs',
#  'RunManager.py',
#  'PyTorchTrainLoop_RunManager.py']

# %%
from importlib.machinery import SourceFileLoader
plotcm = SourceFileLoader('plotcm', join(PROJECT_PATH, 'plotcm.py')).load_module()
Network = SourceFileLoader('Network', join(PROJECT_PATH, 'Network.py')).load_module()
RunBuilder = SourceFileLoader('RunBuilder', join(PROJECT_PATH, 'RunBuilder.py')).load_module()
RunManager = SourceFileLoader('RunManager', join(PROJECT_PATH, 'RunManager.py')).load_module()

pytorchtrainloop = SourceFileLoader('pytorchtrainloop', join(PROJECT_PATH, 'PyTorchTrainLoop_RunManager.py')).load_module()
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
#!ls '$PROJECT_PATH'/runs
#!rm -rf '$PROJECT_PATH'/runs
# Out:
# ls: cannot access '/content/drive/My Drive/Colab Notebooks/Workspace/PyTorchPlayground/runs': No such file or directory

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
log_dir = join(PROJECT_PATH, 'runs')

from tensorboard import notebook
#notebook.list() # View open TensorBoard instances

#%tensorboard --logdir='$PROJECT_PATH'/runs

#notebook.display()

# %%
import torch

pytorchtrainloop.main(PROJECT_PATH)
# Out:
#       run  epoch network      loss  ...  dropout         lin_out   in_size  out_size
# 0       1      1   LeNet  0.923327  ...      0.0       [200, 84]  (28, 28)        10
# 1       1      2   LeNet  0.484469  ...      0.0       [200, 84]  (28, 28)        10
# 2       1      3   LeNet  0.395871  ...      0.0       [200, 84]  (28, 28)        10
# 3       1      4   LeNet  0.355690  ...      0.0       [200, 84]  (28, 28)        10
# 4       1      5   LeNet  0.315109  ...      0.0       [200, 84]  (28, 28)        10
# ...   ...    ...     ...       ...  ...      ...             ...       ...       ...
# 1615  162      6   LeNet  0.658304  ...      0.5  [500, 200, 84]  (28, 28)        10
# 1616  162      7   LeNet  0.650940  ...      0.5  [500, 200, 84]  (28, 28)        10
# 1617  162      8   LeNet  0.625459  ...      0.5  [500, 200, 84]  (28, 28)        10
# 1618  162      9   LeNet  0.614424  ...      0.5  [500, 200, 84]  (28, 28)        10
# ...

# %%
# !sleep 10
runs_folder = os.path.join(PROJECT_PATH, 'runs')
results_csv_file = os.path.join(PROJECT_PATH, 'results.csv')
results_json_file = os.path.join(PROJECT_PATH, 'results.json')
best_models_file = os.path.join(PROJECT_PATH, 'best_models.txt')
#'results.csv'
#!echo '$runs_folder'
#!ls '$runs_folder'
#google.colab.files.download(os.path.join(PROJECT_PATH, 'results.csv'))
#google.colab.files.download(os.path.join(PROJECT_PATH, 'results.json'))
#google.colab.files.download(os.path.join(PROJECT_PATH, 'best_models.txt'))

# !zip -r /content/runs.zip '$runs_folder' '$results_csv_file' '$results_json_file' '$best_models_file'

import google.colab.files
google.colab.files.download("/content/runs.zip")
# Out:
#   adding: content/drive/My Drive/Colab Notebooks/Workspace/PyTorchPlayground/runs/ (stored 0%)
#   adding: content/drive/My Drive/Colab Notebooks/Workspace/PyTorchPlayground/runs/events.out.tfevents.1574591788.11115d38f2b8.124.0-Run(network='LeNet', lr=0.005, batch_size=1000, shuffle=True, epochs=10, device='cuda', nw=2, conv_out=[16, 32], conv_ks=[3, 3], dropout=0.0, lin_out=[200, 84], in_size=(28, 28), out_size=10) (deflated 50%)
#   adding: content/drive/My Drive/Colab Notebooks/Workspace/PyTorchPlayground/runs/events.out.tfevents.1574592011.7202e4b8d0a5.122.0-Run(network='LeNet', lr=0.005, batch_size=1000, shuffle=True, epochs=10, device='cuda', nw=2, conv_out=[16, 32], conv_ks=[3, 3], dropout=0.0, lin_out=[200, 84], in_size=(28, 28), out_size=10) (deflated 51%)
# ...

# %%
#drive.flush_and_unmount()
'''
import google.colab.files
#files.download(os.listdir(os.path.join(PROJECT_PATH, 'runs'))[0])
os.chdir(PROJECT_PATH)
for root, dirs, files in os.walk(os.path.abspath(PROJECT_PATH + '/runs')):
    for file in files:
        print(os.path.join(root, file))
        google.colab.files.download(os.path.join(root, file))
'''
# Out:
# /content/drive/My Drive/Colab Notebooks/Workspace/PyTorchPlayground/runs/events.out.tfevents.1574544730.1c8730f34a07.1013.0-Run(network='LeNet', lr=0.005, batch_size=1000, shuffle=True, epochs=2, device='cuda', nw=2, conv_out=[16, 32], conv_ks=[3, 3], dropout=0.2, lin_out=[200, 84], in_size=(28, 28), out_size=10)
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-10-b58cfd4c478f> in <module>()
#       6     for file in files:
#       7         print(os.path.join(root, file))
# ----> 8         google.colab.files.download(os.path.join(root, file))
#       9
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# ...
